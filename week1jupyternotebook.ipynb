# %%
one = 1
two = 2
three = 3
four = 4
can = "can"
do = "do"
python = "python"
more = "more"
print(one, two, three, four, can, do, python, more)


number1 = 15
number2 = 30

result = number1 * number2
print(" The result is", result)


 #3
def check_first_last(numbers):
    print("Given list:", numbers)
    print("result is", numbers[0] == numbers[-1])

numbers_x = [10, 20, 30, 40, 10]
numbers_y = [75, 65, 35, 75, 30]

check_first_last(numbers_x)
check_first_last(numbers_y)

#4
numbers = [10, 20, 33, 46, 55]
print("Given list is", numbers)
print("Divisible by 5")
for num in numbers:
    if num % 5 == 0:
        print(num)

#5
str_x = "Anjali is good developer. Anjali is a writer"
count = str_x.count("Anjali")
print("Anjali appeared", count, "times")

#6
for i in range(1, 6):
    print((str(i) + " ") * i)

#7
for i in range(1, 11):
    for j in range(1, 11):
        print(i * j, end="\t")
    print()
#8
import numpy as np

Temp_K = [390.65, 107.52, 225.25, 275.98, 318.18, 88.45]
Temp_K_array = np.array(Temp_K)
Temp_C = Temp_K_array - 273.15
print("Temperatures in Celsius:", Temp_C)

#9
import pandas as pd

data = {
    "Student": ["Tommy", "Fred", "Gail", "Tahmidul", "Randy", "Ariel"],
    "Hair Color": ["Brown", "Grey", "Blonde", "Black", "Black", "Brown"],
    "Eye Color": ["Hazel", "Green", "Blue", "Brown", "Hazel", "Blue"],
    "Weight (kg)": [60, 80, 76, 60, 88, 85]
}

df = pd.DataFrame(data)

# Entire dataframe
print("Full DataFrame:")
print(df)

# Hair color column as Series
print("\nHair Color Column (Series):")
print(df["Hair Color"])

# Eye color column as DataFrame
print("\nEye Color Column (DataFrame):")
print(df[["Eye Color"]])

# Student and Weight columns
print("\nStudent and Weight Columns:")
print(df[["Student", "Weight (kg)"]])

# Second to fourth observations (index 1 to 3)
print("\nSecond to Fourth Observations:")
print(df[1:4])
